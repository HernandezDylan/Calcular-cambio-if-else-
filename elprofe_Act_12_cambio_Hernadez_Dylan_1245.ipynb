# %% [markdown]
# <a href="https://colab.research.google.com/github/HernandezDylan/Calcular-cambio-if-else-/blob/main/elprofe_Act_12_cambio_Hernadez_Dylan_1245.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Hernadez Dylan = 59 Fecha 26/mar/26
# #### Calculando el cambio usando if else
# #### Miar diagramas de flujo
# <img src="https://raw.githubusercontent.com/CristopherLopez67/Calcular-cambio-if-else-/refs/heads/main/images%20(1).jfif" alt="Descripción" width="300" height="300">
#
# #### Las variable
# 1. cp --> costo del producto
# 2. CD--> cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $$cambio = CD - CP$
#
#
# ## Digrama de flujo Lucidchat
# <img src="https://raw.githubusercontent.com/HernandezDylan/Calcular-cambio-if-else-/refs/heads/main/Diagrama%20de%20flujo.png"
# alt="Descripcion" width="300" height="300">

# %%
# Para cuando es verdadero
# Calculando el cambio usando if else
# Datos de entrada CD , CP
# Mostrar cambio si es falso
# Si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP >= CD:
    print("No alcanza")
else:
    cambio = CD - CP
    print("El cambio es: ", cambio)
print("Fin del programa")
print("Programa realizado por Hernadez Dylan NL = 25")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Hernadez Dylan NL = 25

# %%
# Para cuando es falso (No)
# Calculando el cambio usando if esle
# Datos de entrada CD , CP
# Mostrar cambio si es falso
# si es verdadero mostar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP >= CD:
    print("No alcanza")
else:
    cambio = CD - CP
    print("El cambio es: ", cambio)
print("Fin del programa")
print("Programa realizado por Hernadez Dylan NL = 25")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# Fin del programa
# Programa realizado por Hernadez Dylan NL = 25

# %% [markdown]
# Relacion dentre diagrama de flujo
# <img src="https://raw.githubusercontent.com/HernandezDylan/Calcular-cambio-if-else-/refs/heads/main/shapes%20at%2026-03-26%2010.16.56.png"
# alt="Descripcion" width="300" height="300">
